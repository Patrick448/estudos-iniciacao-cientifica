# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
def plot_results(path):
    es_1p1 = []
    es_pi = []
    es_pni = []
    D = []
    E = []

    with open(path, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',', quotechar='\'')
        next(reader, None)
        for row in reader:
            es_1p1.append(float(row[0]))
            es_pi.append(float(row[1]))
            es_pni.append(float(row[2]))

    #print(es_1p1)
    #print(es_pi)
    #print(es_pni)

    tabela = [None, None, None]


    def table_row(array):
        row = [f"{np.average(array):.2f}", f"{np.min(array):.2f}", f"{np.max(array):.2f}", f"{np.median(array):.2f}",
               f"{np.std(array):.2f}"]
        return row


    tabela[0] = table_row(es_1p1)
    tabela[1] = table_row(es_pi)
    tabela[2] = table_row(es_pni)

    fig, ax = plt.subplots()
    # hide axes
    fig.patch.set_visible(False)

    ax.axis('off')
    ax.axis('tight')
    colLabels = ['Media', 'Melhor', 'Pior', 'Mediana', 'Desvio Padrão']
    rowLabels = ["(1+1)-ES", "Pop. Iso.", "Pop. N. Iso."]
    table = ax.table(tabela, colLabels=colLabels, rowLabels=rowLabels, loc='center')
    table.scale(3, 2)
    table.set_fontsize(15)
    fig.tight_layout()

    fig_boxplot, ax_boxplot = plt.subplots()
    ax_boxplot.boxplot(x=[es_1p1, es_pi, es_pni], labels=["(1+1)-ES", "Pop. Iso.", "Pop. N. Iso."])

    plt.show()

# %% [markdown]
# # Comparação - 30 execuções - 20000 chamadas de função objetivo
# ### 20 pais, 10 filhos

# %%
plot_results(f'comparison-30runs-20000it-10p-20o.csv')
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_97808\4060710432.py:44: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %% [markdown]
# # Comparação - 30 execuções - 20000 chamadas de função objetivo
# ### 5 pais, 10 filhos

# %%
plot_results(f'comparison-30runs-20000it-5p-10o.csv')
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_97808\4060710432.py:44: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %% [markdown]
# # Comparação - 30 execuções - 10000 chamadas de função objetivo
# ### 5 pais, 10 filhos

# %%
plot_results(f'comparison-30runs-10000it-5p-10o.csv')
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_97808\4060710432.py:44: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %% [markdown]
# # Comparação - 30 execuções - 100000 chamadas de função objetivo
# ### 10 pais, 20 filhos

# %%
plot_results(f'comparison-30runs-100000it-10p-20o.csv')
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_97808\4060710432.py:44: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %% [markdown]
# # Comparação - 30 execuções - 200000 chamadas de função objetivo
# ### 10 pais, 20 filhos

# %%
plot_results(f'comparison-30runs-200000it-10p-20o.csv')
# Out:
# C:\Users\patri\AppData\Local\Temp\ipykernel_97808\4060710432.py:44: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()
