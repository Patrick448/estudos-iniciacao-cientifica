# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
from GRN.src.GRN_aux_10 import diferenca_teste, get_results

# %%
diferenca_teste()
# Out:
# 0.7095 1.2266047174130963 1.602949147929842 1.8735343708232444 2.0677766956549277 2.2025045461071953 1.9487594019469456 1.4157939437175646 1.0170290407181293 0.730127371565163 0.5241185571595731 0.37623053740002926 0.2700737393630102 0.19390104218332785 0.13975242201500404 0.12369916896931675 0.4776197089423206 1.0504494374581035 1.476754640792459 1.7829589575101958 2.0027607241295895 2.1605075569084917 2.2257390574330995 1.7502424579890075 1.2608117865289032 0.9053272743840811 0.6499051033953759 0.4665267300730034 0.3348884837899991 0.24040415657554146 0.1726238240305809 0.12527464093359375 0.14893643125127984 0.6300500567391446 1.1699455949305753 1.5626637764935718 1.844627782094706 2.0470162199371247 2.1920755646691967 2.157450724512385 1.6153838344654 1.161613507699279 0.8339995676084331 0.5986911911756766 0.4297619569960618 0.3085048118927656 0.22146327693365095 0.1590833181045378 0.1176057515224874 0.21601569475494733
# ...

# %%
x = []
original_A = []
original_B = []
original_C = []
original_D = []
original_E = []
original_F = []
original_G = []
original_H = []
original_I = []
original_J = []

with open(f'GRN10.txt', 'r', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=' ', quotechar='\'')
    for row in reader:
       x.append(float(row[0]))
       original_A.append(float(row[1]))
       original_B.append(float(row[2]))
       original_C.append(float(row[3]))
       original_D.append(float(row[4]))
       original_E.append(float(row[5]))
       original_F.append(float(row[6]))
       original_G.append(float(row[7]))
       original_H.append(float(row[8]))
       original_I.append(float(row[9]))
       original_J.append(float(row[10]))

print(max(original_A))
print(max(original_B))
print(max(original_C))
print(max(original_D))
print(max(original_E))
print(max(original_F))
print(max(original_G))
print(max(original_H))
print(max(original_I))
print(max(original_J))

print(x)
print(original_A)
print(original_B)
print(original_C)
print(original_D)
print(original_E)
# Out:
# 2.5619
# 0.9499
# 0.9299
# 0.9475
# 2.5619
# 0.9499
# 0.9299
# 0.9475
# 1.0803
# 2.0445
# [0.0, 1.4694, 2.9388, 4.4082, 5.8776, 7.3469, 8.8163, 10.2857, 11.7551, 13.2245, 14.6939, 16.1633, 17.6327, 19.102, 20.5714, 22.0408, 23.5102, 24.9796, 26.449, 27.9184, 29.3878, 30.8571, 32.3265, 33.7959, 35.2653, 36.7347, 38.2041, 39.6735, 41.1429, 42.6122, 44.0816, 45.551, 47.0204, 48.4898, 49.9592, 51.4286, 52.898, 54.3673, 55.8367, 57.3061, 58.7755, 60.2449, 61.7143, 63.1837, 64.6531, 66.1224, 67.5918, 69.0612, 70.5306, 72.0]
# [0.7095, 1.0491, 1.4361, 1.8408, 2.2268, 2.5163, 2.4952, 1.9836, 1.2177, 0.4737, 0.0599, 0.0345, 0.0607, 0.1108, 0.201, 0.3537, 0.5861, 0.8974, 1.2679, 1.6689, 2.0684, 2.4146, 2.5619, 2.2523, 1.5534, 0.7721, 0.1672, 0.031, 0.0472, 0.0858, 0.1564, 0.2798, 0.4771, 0.7564, 1.105, 1.4967, 1.9012, 2.2797, 2.5406, 2.4481, 1.8763, 1.0989, 0.3795, 0.0443, 0.0372, 0.0664, 0.1213, 0.2194, 0.3832, 0.6281]
# ...

# %%
fig,ax=plt.subplots(1,1)
ax.plot(x, original_A, label='A')
ax.plot(x, original_B, label='B')
ax.plot(x, original_C, label='C')
ax.plot(x, original_D, label='D')
ax.plot(x, original_E, label='E')
ax.plot(x, original_F, label='F')
ax.plot(x, original_G, label='G')
ax.plot(x, original_H, label='H')
ax.plot(x, original_I, label='I')
ax.plot(x, original_J, label='J')
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

print(max(original_A))
print(max(original_B))
print(max(original_C))
print(max(original_D))
print(max(original_F))
print(max(original_G))
print(max(original_H))
print(max(original_I))
print(max(original_J))
# Out:
# 2.5619
# 0.9499
# 0.9299
# 0.9475
# 0.9499
# 0.9299
# 0.9475
# 1.0803
# 2.0445

# %%
ind = {'dim': [1.73,2,0.81,0.11, 1.23, 1.78, 1.14, 1.04, 3.47, 3.21,
                    0.45, 0.56, 0.99, 0.77, 0.71, 0.66, 0.46, 0.48, 0.66, 0.99, 0.85, 0.61, 0.55, 0.46, 0.17,
                    20, 9, 24, 12, 2, 2, 6, 4, 7, 24, 2, 7, 21, 20, 3 ]}

ind2 = {'dim': [1.794959063619618,0.325916390981450,1.373531424500639,4.876320937569907,3.217338401574691,1.110218875631117,2.392018328873477,2.418083472103063,0.197146901846466,2.399121427787891,0.170092865952182,0.681771467943102,0.359744476967681,0.116431120293755,0.213681567803735,0.954201013449119,0.518159605681162,0.156467307915179,0.857891199520864,0.100000000000000,0.630080495172404,0.920976003562880,0.178296671657450,0.730153469559525,0.100000000000000,13.187576247063026,8.445276716025347,1.969573106532458,24.116432156483607,2.076151498086156,12.834449005847529,7.268084680212454,12.662147450344683,1.036395092981174,5.318811857475626,9.946469643555850,21.167378837163223,13.536583027067825,1.107996504931092,21.247369208634349
]}

grn10JE = {'dim': [1.73,2,0.81,0.11, 1.23, 1.78,
                      1.14, 1.04, 3.47, 3.21, 0.45,
                      0.56, 0.99, 0.77, 0.71, 0.66,
                      0.46, 0.48, 0.66, 0.99, 0.85,
                      0.61, 0.55, 0.46, 0.17, 20,
                      9, 24, 12, 2, 2, 6, 4, 7,
                      24, 2, 7, 21, 20, 3]}

# %%
grn10LSODA = {'dim': [1.341477484494165,2.781988058549157,3.490801172024773,1.257405539049150,1.297877597005905,1.894733240422617,1.195647059919179,2.270689758542591,2.600165483392267,3.875174338136099,0.453263240515180,0.555610042754187,0.285563160958080,0.149847316813419,0.595921539913905,0.548793613457920,0.445576631784505,0.611426963353202,0.963894321103912,0.800389957453789,0.726097076792202,0.556277329691692,0.347780603967589,0.496289170889362,0.141357730089877,21.337791438025970,6.605888183782290,9.526528498220566,5.107497299110702,12.852852358990023,2.913101110229551,14.518643891321348,23.433342043901426,17.753610354070797,15.274313164854433,2.474490287268817,8.562945910662774,18.767135978268104,10.472219420614113,4.679502740145083
]}

grn10Rk4 = {'dim': [1.489329188828929,2.062827136863578,2.466693136996797,1.008970881722796,1.383377856627157,1.751599284440565,2.067563102458654,2.095762844223213,2.167467614156068,4.270428933060529,0.439420794498028,0.602011679139360,0.181558466954136,0.130421029101338,0.617069980996292,0.561966784806900,0.438473280184997,0.606482192840012,0.775841692624209,0.737890971748534,0.643435464700540,0.541978986016550,0.337217522924080,0.585893978842659,0.115420565073943,18.319872668579741,8.082141746085680,24.474344769568872,18.734592194320075,17.869240614166248,2.941831945890582,21.465083399236817,23.021345075873931,3.796594597764678,21.391040597238053,14.727404404753924,24.954599191392553,14.635733373140352,14.765589037867480,7.675430056421228
]}

A, B, C, D, E, F, G, H, I, J= [], [], [], [], [], [], [], [], [], []

def plot_comp(original, new):
    #print(original)
    #print(new)

    fig, ax = plt.subplots(1, 1)
    ax.plot(x, original, label='Orig.', marker=".")
    ax.plot(x, new, label='New', marker=".")

    ax.legend()
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    plt.show()

def plot_ind(individual_params):
    local_A,local_B,local_C,local_D,local_E,local_F,local_G,local_H,local_I,local_J = get_results(individual_params)
    x = []

    with open(f'GRN5.txt', 'r', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=' ', quotechar='\'')
        for row in reader:
            x.append(float(row[0]))

    #print(x)
    #print(local_A)
    #print(local_B)
    #print(local_C)
    #print(local_D)
    #print(local_E)

    fig, ax = plt.subplots(1, 1)
    ax.plot(x, local_A, label='A')
    ax.plot(x, local_B, label='B')
    ax.plot(x, local_C, label='C')
    ax.plot(x, local_D, label='D')
    ax.plot(x, local_E, label='E')
    ax.plot(x, local_F, label='F')
    ax.plot(x, local_G, label='G')
    ax.plot(x, local_H, label='H')
    ax.plot(x, local_I, label='I')
    ax.plot(x, local_J, label='J')
    ax.legend()
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    plt.show()

    plot_comp(original_A, local_A)
    plot_comp(original_B, local_B)
    plot_comp(original_C, local_C)
    plot_comp(original_D, local_D)
    plot_comp(original_E, local_E)
    plot_comp(original_F, local_F)
    plot_comp(original_G, local_G)
    plot_comp(original_H, local_H)
    plot_comp(original_I, local_I)
    plot_comp(original_J, local_J)

# %%
plot_ind(grn10JE['dim'])
plot_ind(grn10LSODA['dim'])
plot_ind(grn10Rk4['dim'])
# Out:
# 56.74712045779758
# 54.211288148741005
# 53.795738844906275
