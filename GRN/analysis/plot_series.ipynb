# %%
import matplotlib.pyplot as plt
import pandas as pd
import string

def plot_comparison(actual_series, predicted_series, train_pred=None, save_to=None):
    
    for col in predicted_series.columns:
        comparison_df = pd.DataFrame({'ac':actual_series[col], 'pr':predicted_series[col], 'tr':train_pred[col] if train_pred is not None else ''})
        ax = comparison_df.plot(marker='o', color = ['#9A7787', '#E4AFB0', '#FED7BF'])
        #ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
        plt.ylabel("Concentration", fontsize=14)
        plt.xticks(fontsize=16)
        plt.yticks(fontsize=16)
        
        plt.legend(['Real', 'Test', 'Train'], fontsize=16, loc=1)
        fig = plt.gcf() 
        fig.set_size_inches(8, 3)   
        #plt.savefig("A.eps", dpi=300)
        if save_to:
            plt.savefig(f'{save_to}/output_{col}.png', dpi=300)
        plt.show()

# %% [markdown]
# ## Modelo de 5 variáveis

# %%
actual_series_grn5new= pd.read_csv('GRN5_DATA.txt', index_col=0, sep="\t", header=None,names=list(string.ascii_uppercase[:6]))
actual_series_grn5new.drop(columns=['F'], inplace=True)
actual_series_grn5new[51.428600:].plot(marker='o', title="Actual")

pred_grn5new = pd.read_csv('../results/grn5new-1050000/grn5new_best_test.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]),)
pred_grn5new.plot(marker='o', title="Predicted")

train_grn5new = pd.read_csv('../results/grn5new-1050000/grn5new_best_train.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]),)

plot_comparison(actual_series_grn5new, pred_grn5new, train_grn5new, save_to='graficos/grn5')

# %% [markdown]
# ## Modelo de 10 variáveis

# %%
actual_series = pd.read_csv('GRN10_DATA.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:11]))
actual_series.drop(columns=['K'], inplace=True)
actual_series[51.4286:].plot(marker='o', title="Actual")

pred = pd.read_csv('../results/grn10new2-1050000/grn10new2_best_test.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:10]))
pred.plot(marker='o', title="Predicted")

train_pred = pd.read_csv('../results/grn10new2-1050000/grn10new2_best_train.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:10]))

plot_comparison(actual_series, pred, train_pred, save_to="graficos/grn10")

# %% [markdown]
# ## Modelo de 4 variáveis - não cíclico

# %%
actual_series_genesABDC = pd.read_csv('genesABCD_data.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]))
actual_series_genesABDC.drop(columns=['E'], inplace=True)
actual_series_genesABDC[22.6233:].plot(marker='o', title="Actual")

pred_genesABCD = pd.read_csv('../results/grn4ncyc-1050000/grn4ncyc(genes_abcd)_best_test.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:4]))
pred_genesABCD.plot(marker='o', title="Predicted")


train_genesABCD = pd.read_csv('../results/grn4ncyc-1050000/grn4ncyc(genes_abcd)_best_train.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:4]))

plot_comparison(actual_series_genesABDC, pred_genesABCD, train_genesABCD)

# %% [markdown]
# ## Modelo de 4 variáveis - não cíclico (NORMALIZAÇÃO)

# %%
actual_series_genesABDC = pd.read_csv('genesABCD_data.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]))
actual_series_genesABDC.drop(columns=['E'], inplace=True)
actual_series_genesABDC[22.6233:].plot(marker='o', title="Actual")

pred_genesABCD = pd.read_csv('../results/grn4ncyc-1050000-norm2/grn4ncyc_best_test.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:4]))
pred_genesABCD.plot(marker='o', title="Predicted")


train_genesABCD = pd.read_csv('../results/grn4ncyc-1050000-norm2/grn4ncyc_best_train.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:4]))


plot_comparison(actual_series_genesABDC, pred_genesABCD, train_genesABCD)

# %% [markdown]
# ## Modelo de 4 variáveis - não cíclico (NORMALIZAÇÃO) - PONTOS DE TREINO INTERPOLADOS

# %%
actual_series_genesABDC = pd.read_csv('genesABCD_data.txt', index_col=0, sep="\t", header=None,
                                      names=list(string.ascii_uppercase[:5]))
actual_series_genesABDC.drop(columns=['E'], inplace=True)
actual_series_genesABDC[22.6233:].plot(marker='o', title="Actual")

pred_genesABCD = pd.read_csv('../results/grn4ncyc-1050000-interp/grn4ncyc_best_test.txt', index_col=0, sep="\t",
                             header=None, names=list(string.ascii_uppercase[:4]))
pred_genesABCD.plot(marker='o', title="Predicted")

train_genesABCD = pd.read_csv('../results/grn4ncyc-1050000-interp/grn4ncyc_best_train.txt', index_col=0, sep="\t",
                              header=None, names=list(string.ascii_uppercase[:4]))

plot_comparison(actual_series_genesABDC, pred_genesABCD, train_genesABCD)

# %% [markdown]
# ## Modelo de 5 variáveis - não cíclico

# %%
actual_series_dadosZED= pd.read_csv('DadosZeEduardo_DATA.txt', index_col=0, sep="\t", header=None,names=list(string.ascii_uppercase[:6]))
actual_series_dadosZED.drop(columns=['F'], inplace=True)
actual_series_dadosZED[21.3048:].plot(marker='o', title="Actual")

pred_grn5ncyc = pd.read_csv('../results/grn5ncyc-1050000/grn5ncyc_best_test.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]),)
pred_grn5ncyc.plot(marker='o', title="Predicted")

train_pred_grn5ncyc = pd.read_csv('../results/grn5ncyc-1050000/grn5ncyc_best_train.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]),)



plot_comparison(actual_series_dadosZED, pred_grn5ncyc, train_pred_grn5ncyc)

# %% [markdown]
# ## Modelo de 5 variáveis - não cíclico (NORMALIZAÇÃO)

# %%
actual_series_dadosZED= pd.read_csv('DadosZeEduardo_DATA.txt', index_col=0, sep="\t", header=None,names=list(string.ascii_uppercase[:6]))
actual_series_dadosZED.drop(columns=['F'], inplace=True)
actual_series_dadosZED[21.3048:].plot(marker='o', title="Actual")

pred_grn5ncyc = pd.read_csv('../results/grn5ncyc-1050000-norm2/grn5ncyc_best_test.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]),)
pred_grn5ncyc.plot(marker='o', title="Predicted")

train_pred_grn5ncyc = pd.read_csv('../results/grn5ncyc-1050000-norm2/grn5ncyc_best_train.txt', index_col=0, sep="\t", header=None, names=list(string.ascii_uppercase[:5]),)


plot_comparison(actual_series_dadosZED, pred_grn5ncyc, train_pred_grn5ncyc)

# %% [markdown]
# ## Modelo de 5 variáveis -
