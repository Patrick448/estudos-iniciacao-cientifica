# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
from GRN.src.GRN_aux_5 import get_result_static, get_results, get_results_new, diferenca_teste

# %%
diferenca_teste()
# Out:
# [[0.7095     0.1767     0.1522     0.0806     0.7095    ]
#  [1.44578035 0.23089997 0.04952732 0.03246956 0.52916428]
#  [1.94204656 0.40284739 0.05978905 0.01289308 0.39466502]
#  [2.27568709 0.60061314 0.1692431  0.00691395 0.29435184]
#  [2.4999753  0.78504293 0.34149026 0.0413724  0.21953556]
#  [2.65074318 0.94657084 0.51026493 0.20317702 0.16373883]
#  [2.75210421 1.08452318 0.64170153 0.43299177 0.12423497]
#  [2.82024347 1.2008594  0.73417942 0.61671532 0.29608276]
#  [2.86596503 1.2982609  0.79716409 0.73403937 0.58459   ]
#  [2.88753686 1.37936913 0.84016478 0.80338245 0.80646867]
#  [2.78429417 1.44527614 0.86991399 0.843755   0.97251133]
#  [2.38732196 1.48990531 0.88986852 0.86747573 1.09647334]
#  [1.84493298 1.49150898 0.89946161 0.88107928 1.18897009]
#  [1.35701966 1.41388425 0.89238387 0.88669538 1.25796938]
#  [0.97871203 1.2531836  0.85627999 0.8820574  1.30943598]
#  [0.70165998 1.06132969 0.7802219  0.85872195 1.34779615]
# ...

# %%
x = []
original_A = []
original_B = []
original_C = []
original_D = []
original_E = []
with open(f'GRN5.txt', 'r', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=' ', quotechar='\'')
    for row in reader:
       x.append(float(row[0]))
       original_A.append(float(row[1]))
       original_B.append(float(row[2]))
       original_C.append(float(row[3]))
       original_D.append(float(row[4]))
       original_E.append(float(row[5]))

print(x)
print(original_A)
print(original_B)
print(original_C)
print(original_D)
print(original_E)

for i in range(len(x)):
    print(f'{x[i]}\t{original_A[i]}\t{original_B[i]}\t{original_C[i]}\t{original_D[i]}\t{original_E[i]}')
# Out:
# [0.0, 1.4694, 2.9388, 4.4082, 5.8776, 7.3469, 8.8163, 10.2857, 11.7551, 13.2245, 14.6939, 16.1633, 17.6327, 19.102, 20.5714, 22.0408, 23.5102, 24.9796, 26.449, 27.9184, 29.3878, 30.8571, 32.3265, 33.7959, 35.2653, 36.7347, 38.2041, 39.6735, 41.1429, 42.6122, 44.0816, 45.551, 47.0204, 48.4898, 49.9592, 51.4286, 52.898, 54.3673, 55.8367, 57.3061, 58.7755, 60.2449, 61.7143, 63.1837, 64.6531, 66.1224, 67.5918, 69.0612, 70.5306, 72.0]
# [0.7095, 1.1517, 1.5655, 1.936, 2.2733, 2.5756, 2.8212, 2.96, 2.9254, 2.6869, 2.2836, 1.7915, 1.2869, 0.8431, 0.5413, 0.4613, 0.6496, 1.0269, 1.4313, 1.8054, 2.1465, 2.4532, 2.7094, 2.8754, 2.8912, 2.7152, 2.3661, 1.9094, 1.4201, 0.9706, 0.6387, 0.5072, 0.6356, 0.9783, 1.3772, 1.7534, 2.0975, 2.408, 2.6711, 2.8508, 2.8892, 2.74, 2.4132, 1.9696, 1.4838, 1.0279, 0.6786, 0.5188, 0.614, 0.9369]
# ...

# %%
fig,ax=plt.subplots(1,1)
ax.plot(x, original_A, label='A')
ax.plot(x, original_B, label='B')
ax.plot(x, original_C, label='C')
ax.plot(x, original_D, label='D')
ax.plot(x, original_E, label='E')
ax.legend()
ax.set_xlabel('x')
ax.set_ylabel('y')
plt.show()

print(max(original_A))
print(max(original_B))
print(max(original_C))
print(max(original_D))
print(max(original_E))
# Out:
# 2.96
# 1.8768
# 1.0653
# 1.0101
# 1.4608

# %%
#ind = {'dim': [2.62, 3.65, 0.57, 4.00, 4.85, 1, 0.28, 0.34, 0.91, 0.50, 4.84, 23.26, 21.34, 14.02, 12.49], 'sigma': 0.0005448244797126596, 'eval': 101.08519788882836}

#ind2 =  {'dim': [0.50, 2.65, 2.41, 3.18, 3.6, 0.9, 0.64, 0.49, 0.54, 0.52, 3.8, 24.0, 20.75, 13.36, 12.53], 'sigma': 0.0003442283429532025, 'eval': 37.92145494105599}

#ind4 =  {'dim': [1.27, 0.56, 4.37, 0.30, 3.16, 0.87, 0.68, 0.41, 0.64, 0.38, 17.15, 6.18, 8.45, 1.02, 6.86], 'sigma': 0.0003442283429532025, 'eval': 37.92145494105599}

#ind3 =  {'dim': [1.25, 4, 1.02, 1.57, 3.43, 0.72, 0.5, 0.45, 0.51, 0.52, 13, 4, 3, 4, 16]}

#ind5 =  {'dim': [1.156015691769711,2.312623267886374,0.823774791733179,3.462459293216292,2.796574501946954,0.507983951979185,0.521732178277992,0.302791113941939,0.731448950667245,0.559818035683460,4.872108211566042,22.429701798044199,2.540760175225613,11.398318561985487,10.603389838996791]}

#ind6 = {'dim':[1.387421965645008,2.246320772303499,1.415595596206390,2.500998984777249,1.456904146610542,0.716422078256141,0.584770492210328,0.408071367440587,0.401113468054924,0.463626175230202,19.715303259438446,9.686342778903812,3.523894897035640,1.034098030405105,4.121362586345466]} #erro 26.234978648752800

#ind7 = {'dim': [1.5729568849769477, 2.5955327708654807, 2.136332937247125, 0.7886524688367416, 1.9800428051007384, 0.7455790621556536, 0.500391448691633, 0.4540307643566215, 0.46551440210785605, 0.6169411110203465, 18.438008622609487, 4.227771327084559, 6.796567148167035, 3.789842431522958, 8.377614424033844], 'sigma': 0.002815144280657883, 'eval': 29.446785891352647}


#best_exp1_cpp ={'dim':[1.299688086160294,2.381687661203559,0.609099261339772,3.313430568888469,1.925476573025173,0.738825443688454,0.580149691889738,0.390092796716386,0.525475411417882,0.412347705980471,19.949539734023197,9.623754787602006,3.762147980419171,3.045561990857736,3.201782763371390], 'eval':25.365675675043348}

ind = {'dim': [1.2163355099083872, 1.1264485098219865, 2.973714367061704,
                     2.952143123315177, 2.998260518457365, 0.5687249950503857,
                     0.4580723119903261, 0.46214892372246563, 0.6182568295500336,
                     0.5213082492659304, 0.7708877748759901, 0.1497642024548283,
                     4.254757908429968, 3.759370669969996, 4.784173526119725,
                     10.935884810737809, 24.595975874929724, 2.8109199678182635,
                     4.922623602327875]}

ind2 = {'dim': [0.1,5,0.851307,3.865580,0.1,
                        0.100000,1.000000,0.100000,0.100000,1.000000,
                        1.000000,0.100000,1.224451,6.558196,13.511094,
                        5.650953,22.882314,11.149282,1.000000]}

grn5JE = {'dim': [1.2163355099083872, 1.1264485098219865, 2.973714367061704,2.952143123315177, 2.998260518457365, 0.5687249950503857,0.4580723119903261, 0.46214892372246563, 0.6182568295500336,0.5213082492659304, 0.7708877748759901, 0.1497642024548283,4.254757908429968, 3.759370669969996, 4.784173526119725,10.935884810737809, 24.595975874929724, 2.8109199678182635, 4.922623602327875]}

grn5LSODA = {'dim': [1.665646732900410,1.897082684353816,0.975275873852489,2.754224014420573,1.488627162874155,0.752016124775905,0.495947143189699,0.368164433824998,0.583010534063372,0.205779564337342,0.936697961205079,0.400650164836070,24.067578711761704,4.637921569111548,2.354220086101498,7.573632383254259,8.917490424828676,1.877741133565334,11.860179163338651]}

grn5RK4 = {'dim': [1.518554824237679,2.284887473830299,2.531733480619191,3.101832922846902,3.654114122147231,0.639299087190237,0.527395640667198,0.449695328381246,0.515082711535552,0.768632056509851,0.146877830910628,0.862094052969164,11.633621817985625,11.610292860148797,5.901302837857914,5.849849277135502,19.589630238693416,7.525159048136441,4.056707716932873]}

ind_new = {'dim':[1.497972,2.119399,1.946335,2.480864,2.467262,0.736679,0.546816,0.411665,0.538214,0.280250,0.836705,0.101934,17.822691,6.735335,3.675051,4.358583,5.638376,1.277956,23.155313]}

ind_best_cmaes = {'dim':[1.520545240399408,2.139288198864691,1.341534080506529,2.969607791711140,3.647946061762784,0.657988355074105,0.543088044985694,0.346809618581652,0.599818152883215,0.603750383928385,0.100000000038187,0.845406318281898,14.005543761143805,6.122146986826940,2.322389725149355,6.872232726720509,9.082611289183956,1.874266945928419,5.645576105292417,5.609062415940282]}



A, B, C, D, E = [], [], [], [], []

def plot_comp(original, new):
    #print(original)
    #print(new)

    fig, ax = plt.subplots(1, 1)
    ax.plot(x, original, label='Orig.', marker=".")
    ax.plot(x, new, label='New', marker=".")

    ax.legend()
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    plt.show()

def plot_ind(individual_params):
    local_A,local_B,local_C,local_D,local_E = get_results_new(individual_params)
    x = []

    with open(f'GRN5.txt', 'r', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=' ', quotechar='\'')
        for row in reader:
            x.append(float(row[0]))

    #print(x)
    #print(local_A)
    #print(local_B)
    #print(local_C)
    #print(local_D)
    #print(local_E)

    fig, ax = plt.subplots(1, 1)
    ax.plot(x, local_A, label='A')
    ax.plot(x, local_B, label='B')
    ax.plot(x, local_C, label='C')
    ax.plot(x, local_D, label='D')
    ax.plot(x, local_E, label='E')
    ax.legend()
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    plt.show()

    plot_comp(original_A, local_A)
    plot_comp(original_B, local_B)
    plot_comp(original_C, local_C)
    plot_comp(original_D, local_D)
    plot_comp(original_E, local_E)

    for i in range(len(x)):
        print(f'{x[i]:.6f}\t{local_A[i]:.6f}\t{local_B[i]:.6f}\t{local_C[i]:.6f}\t{local_D[i]:.6f}\t{local_E[i]:.6f}')

# %%
plot_ind(ind_best_cmaes['dim'])
# Out:
# 20.64242442565574
# 0.000000	0.709500	0.176700	0.152200	0.080600	0.709500
# 1.469400	1.333523	0.178523	0.095331	0.049404	0.543019
# 2.938800	1.786492	0.398138	0.149375	0.030285	0.413026
# 4.408200	2.113356	0.716883	0.355554	0.021463	0.313892
# 5.877600	2.349178	1.003097	0.570547	0.077918	0.250486
# 7.346900	2.519304	1.227477	0.719152	0.257689	0.296702
# 8.816300	2.642051	1.395116	0.808910	0.452730	0.443361
# 10.285700	2.730238	1.517715	0.861303	0.604674	0.609578
# 11.755100	2.782224	1.606243	0.892125	0.711397	0.769063
# 13.224500	2.687064	1.667312	0.910629	0.783396	0.925618
# 14.693900	2.223495	1.688500	0.921113	0.830986	1.091572
# 16.163300	1.652954	1.587868	0.921116	0.861426	1.273931
# 17.632700	1.199269	1.280285	0.894188	0.877055	1.441813
# 19.102000	0.867518	0.925720	0.816813	0.870756	1.447811
# 20.571400	0.631513	0.647889	0.682974	0.813367	1.311969
# 22.040800	0.485332	0.450279	0.514007	0.651368	1.148897
# 23.510200	0.549659	0.312743	0.348117	0.433547	0.964937
# ...
