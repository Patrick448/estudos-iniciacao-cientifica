# %%
import matplotlib.pyplot as plt
import numpy as np
import csv
import pandas as pd

def get_comparison_df(experiment_folder, experiment_prefix, alg_names):
    algs_dfs = []
    comparison_dict = {}
    for alg_name in alg_names:
        algs_dfs.append(pd.read_csv(f'../results/{experiment_folder}/output-{experiment_prefix}-{alg_name}.csv', index_col=False))
    
    for i,alg_name in enumerate(alg_names):
        comparison_dict[alg_name] = algs_dfs[i]['eval']
    
    return pd.DataFrame(comparison_dict)

# %% [markdown]
# # Comparação
#
# Comparação entre os seguintes métodos:
# <br>CMAES
# <br>(15+105)-ES isotrópico
# <br>(15+105)-ES não isotrópico
# <br>DE
# <br>SADE

# %% [markdown]
# # GRN com 5 variáveis - 1050000 chamadas

# %%
get_comparison_df('grn5new-1050000','grn5new', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# # GRN com 10 variáveis - 1050000 chamadas

# %%
get_comparison_df('grn10new2-1050000','grn10new2', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# # GRN com 10 variáveis - 2100000 chamadas

# %%
get_comparison_df('grn10new2-2100000','grn10new2', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## GRN com 4 variáveis - não cíclico - 1050000 chamadas

# %%
get_comparison_df('grn4ncyc-1050000','grn4ncyc', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## GRN com 4 variáveis - não cíclico - 1050000 chamadas (NORMALIZAÇÃO)

# %%
get_comparison_df('grn4ncyc-1050000-norm2','grn4ncyc', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## GRN com 4 variáveis - não cíclico - 1050000 chamadas (NORMALIZAÇÃO - MAX)

# %%
get_comparison_df('grn4ncyc-1050000-norm3', 'grn4ncyc', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(
    column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## GRN com 4 variáveis - não cíclico - 1050000 chamadas (NORMALIZAÇÃO) - PONTOS DE TREINO INTERPOLADOS

# %%
get_comparison_df('grn4ncyc-1050000-interp', 'grn4ncyc', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(
    column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## GRN com 5 variáveis - não cíclico - 1050000 chamadas

# %%
get_comparison_df('grn5ncyc-1050000-test','grn5ncyc', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## GRN com 5 variáveis - não cíclico - 1050000 chamadas (NORMALIZAÇÃO)

# %%
get_comparison_df('grn5ncyc-1050000-norm2','grn5ncyc', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## GRN com 5 variáveis - não cíclico - 1050000 chamadas (NORMALIZAÇÃO - MAX)

# %%
get_comparison_df('grn5ncyc-1050000-norm3', 'grn5ncyc', ['cmaes', 'de', 'sade', 'es-i', 'es-ni']).boxplot(
    column=['cmaes', 'de', 'sade', 'es-i', 'es-ni'])
plt.show()

# %% [markdown]
# ## Comparação entre todos os algoritmos para o modelo de 10 variáveis e o SADE com MIN_N = 0

# %%
n0_comparison = get_comparison_df('grn10new2-1050000','grn10new2', ['cmaes', 'de', 'sade', 'es-i', 'es-ni'])

n0_comparison['saden0'] = get_comparison_df('grn10new2n0','grn10new2', ['sade'])['sade']

n0_comparison.boxplot(column=['cmaes', 'de', 'sade', 'es-i', 'es-ni', 'saden0'])
plt.show()
