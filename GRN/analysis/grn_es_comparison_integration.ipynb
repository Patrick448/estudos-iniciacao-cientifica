# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %%
def plot_results(path,num_algorithms):
    #num_algorithms = 5
    results = [[] for n in range(num_algorithms)]

    with open(path, 'r', newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',', quotechar='\'')
        labels = next(reader)
        for row in reader:
            for i in range(num_algorithms):
                results[i].append(float(row[i]))

    tabela = [None]*num_algorithms

    def table_row(array):
        row = [f"{np.average(array):.2f}", f"{np.min(array):.2f}", f"{np.max(array):.2f}", f"{np.median(array):.2f}",
               f"{np.std(array):.2f}"]
        return row

    for i in range(num_algorithms):
        tabela[i] = table_row(results[i])

    fig, ax = plt.subplots()
    # hide axes
    fig.patch.set_visible(False)

    ax.axis('off')
    ax.axis('tight')
    colLabels = ['Media', 'Melhor', 'Pior', 'Mediana', 'Desvio Padrão']
    #rowLabels = ["(1+1)-ES", "Pop. Iso.", "Pop. N. Iso."]
    table = ax.table(tabela, colLabels=colLabels, rowLabels=labels, loc='center')
    table.scale(3, 2)
    table.set_fontsize(15)
    fig.tight_layout()

    fig_boxplot, ax_boxplot = plt.subplots()
    ax_boxplot.boxplot(x=results, labels=labels)

    plt.show()

def avg_from_file(filepath):
   with open(filepath, 'r', newline='') as csvfile:
    reader = csv.reader(csvfile, delimiter=',', quotechar='\'')
    sum =0;
    row_0 = list(reader)[0];
    empty_cells = 0
    for value in row_0:
        if value == '':
            empty_cells += 1
        else:
            sum += float(value)

    return sum/(len(row_0) - empty_cells)

# %% [markdown]
# # Comparação
#
# Comparação entre os seguintes métodos:
# <br>(1+1)-ES
# <br>(10+20)-ES isotrópico
# <br>(10+20)-ES não isotrópico

# %% [markdown]
# ## 30 execuções - 200000 chamadas de função objetivo

# %%
plot_results(f'../results/exp15/grn5-lsoda-30runs-200000evals.csv',3)
# Out:
# /tmp/ipykernel_20208/1465990086.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %%
plot_results(f'../results/exp15/grn5-rk4-30runs-200000evals.csv',3)
# Out:
# /tmp/ipykernel_20208/1465990086.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %%
plot_results(f'../results/exp15/grn10-lsoda-30runs-200000evals.csv',3)
# Out:
# /tmp/ipykernel_20208/1465990086.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %%
plot_results(f'../results/exp15/grn10-rk4-30runs-200000evals.csv',3)
# Out:
# /tmp/ipykernel_20208/1465990086.py:33: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   fig.tight_layout()

# %%
print(f"Average time for each run: {avg_from_file('../results/exp15/grn5-lsoda-30runs-200000evals -time.csv')}")

print(f"Average time for each run: {avg_from_file('../results/exp15/grn5-rk4-30runs-200000evals -time.csv')}")

print(f"Average time for each run: {avg_from_file('../results/exp15/grn10-lsoda-30runs-200000evals -time.csv')}")

print(f"Average time for each run: {avg_from_file('../results/exp15/grn10-rk4-30runs-200000evals -time.csv')}")
# Out:
# Average time for each run: 321.1
# Average time for each run: 2263.8333333333335
# Average time for each run: 2349.4333333333334
# Average time for each run: 11372.857142857143
