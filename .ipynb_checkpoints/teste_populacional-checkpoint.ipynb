# %%
from ES import populational_isotropic_ES, populational_non_isotropic_ES
import matplotlib.pyplot as plt

# %% [markdown]
# # ES populacionais
# ## ES isotrópico

# %%
def allowed_interval(**kwargs):
    if -10 <= kwargs['x'] <= 10 and -10 <= kwargs['y'] <= 10:
        return True
    return False

res = populational_isotropic_ES(expr="(x + 2*y - 7)^2 + (2*x + y - 5)^2", validator=allowed_interval,dimension_gen_interval=(-10, 10),  iter=20, seed=0, num_parents=100, num_offspring=10)

# %%
x_array = [i['dim']['x'] for i in res]
y_array = [i['dim']['y'] for i in res]

plt.plot(x_array, y_array, 'ro')
plt.axis([-10, 10, -10, 10])
plt.show()

# %%
def allowed_interval(**kwargs):
    if -10 <= kwargs['x'] <= 10 and -10 <= kwargs['y'] <= 10:
        return True
    return False

res = populational_isotropic_ES(expr="- abs (sin(x)*cos(y)*exp(abs(1 - ((sqrt(x^2 +y^2))/PI))))", validator=allowed_interval, dimension_gen_interval=(-10, 10), sigma_var=0.5, iter=10, seed=0, num_parents=1000, num_offspring=10)

# %%
x_array = [i['dim']['x'] for i in res]
y_array = [i['dim']['y'] for i in res]

plt.plot(x_array, y_array, 'ro')
plt.axis([-10, 10, -10, 10])
plt.show()
print('\n'.join([str(d) for d in res]))

print(x_array)
print(y_array)
# Out:
# {'dim': {'x': -8.057315777678765, 'y': -9.666012845139175}, 'sigma': 0.1583177774156324, 'eval': -19.208429553688703}
# {'dim': {'x': 8.064483737974683, 'y': 9.665244045542954}, 'sigma': 0.211631371346242, 'eval': -19.20761321239838}
# {'dim': {'x': -8.062277922472175, 'y': 9.678791612492136}, 'sigma': 0.2660171280957012, 'eval': -19.2059211056622}
# {'dim': {'x': -8.048122632616868, 'y': -9.679388029939542}, 'sigma': 0.14014433408717664, 'eval': -19.205845478796192}
# {'dim': {'x': -8.06823355617428, 'y': 9.674786704855492}, 'sigma': 0.09452793106707766, 'eval': -19.205697089933597}
# {'dim': {'x': 8.038892895040995, 'y': 9.658044984271514}, 'sigma': 0.4993212744475339, 'eval': -19.205486412163527}
# {'dim': {'x': -8.035448699610106, 'y': -9.664340225989916}, 'sigma': 0.5285079674452147, 'eval': -19.20473313527537}
# {'dim': {'x': 8.077149178674029, 'y': -9.66236930584156}, 'sigma': 0.10910314381546941, 'eval': -19.203623181145613}
# ...

# %%
def allowed_interval(**kwargs):
    if -15 <= kwargs['x'] <= -5 and -3 <= kwargs['y'] <= 3:
        return True
    return False


res = populational_isotropic_ES(expr="100*sqrt(abs(y-0.01*x^2)) + 0.01*abs(x+10)", validator=allowed_interval,
                      dimension_gen_interval=(-15, 15), sigma_var=0.5, iter=10, seed=0, num_parents=1000,
                      num_offspring=10)

# %%
x_array = [i['dim']['x'] for i in res]
y_array = [i['dim']['y'] for i in res]

plt.plot(x_array, y_array, 'ro')
plt.axis([-13,-5, -4, 6])
plt.show()
print('\n'.join([str(d) for d in res]))
# Out:
# {'dim': {'y': 2.083106248532437, 'x': -14.433110071187658}, 'sigma': 0.45167825329740735, 'eval': 0.6800569673308984}
# {'dim': {'y': 0.4708764045891576, 'x': -6.861666184696402}, 'sigma': 0.5215119288972029, 'eval': 0.750940751406448}
# {'dim': {'y': 1.3002963113522383, 'x': -11.402559174880558}, 'sigma': 0.372411758225391, 'eval': 1.0758823886390507}
# {'dim': {'y': 1.0500309358069868, 'x': -10.248212730309357}, 'sigma': 0.36781350931297324, 'eval': 1.5114746712238372}
# {'dim': {'y': 0.6915560105174411, 'x': -8.317662865462179}, 'sigma': 0.060831636874211184, 'eval': 1.6875864228995237}
# {'dim': {'y': 0.6814796439415328, 'x': -8.25687234142693}, 'sigma': 0.10039076866225584, 'eval': 1.6900480428466667}
# {'dim': {'y': 0.9841465804527558, 'x': -9.921861385763327}, 'sigma': 0.8600083470390406, 'eval': 1.6941600509950718}
# {'dim': {'y': 1.403355941208826, 'x': -11.84755108233892}, 'sigma': 0.18674727515591685, 'eval': 1.7176673112846457}
# ...

# %% [markdown]
# ## ES não isotrópico

# %%
def allowed_interval(**kwargs):
    if -10 <= kwargs['x'] <= 10 and -10 <= kwargs['y'] <= 10:
        return True
    return False


res = populational_non_isotropic_ES(expr="(x + 2*y - 7)^2 + (2*x + y - 5)^2",
                                validator=allowed_interval, dimension_gen_interval=(-10, 10), sigma_var=0.5, iter=50,
                                seed=0, num_parents=1000, num_offspring=10)

x_array = [i['dim']['x'] for i in res]
y_array = [i['dim']['y'] for i in res]

plt.plot(x_array, y_array, 'ro')
plt.axis([-10, 10, -10, 10])
plt.show()
print('\n'.join([str(d) for d in res]))

print(x_array)
print(y_array)
# Out:
# {'dim': {'x': 0.9999400343331859, 'y': 3.000082649240426}, 'sigma': {'x': 0.005209767220803194, 'y': 0.007592874031157846}, 'eval': 1.2484956186590658e-08}
# {'dim': {'x': 1.000216437989995, 'y': 2.9997784526519973}, 'sigma': {'x': 0.006255017018283689, 'y': 0.008809680422847672}, 'eval': 9.60330530770815e-08}
# {'dim': {'x': 0.9996272869123247, 'y': 3.0003586298351617}, 'sigma': {'x': 0.012778693872015972, 'y': 0.04274267898539566}, 'eval': 2.6832375639791334e-07}
# {'dim': {'x': 0.9998201456543355, 'y': 3.0003714108549016}, 'sigma': {'x': 0.009371393795564975, 'y': 0.016651724638437528}, 'eval': 3.1706919371735046e-07}
# {'dim': {'x': 1.0001959973377728, 'y': 2.999533860625571}, 'sigma': {'x': 0.005475879856019586, 'y': 0.0020087600982476475}, 'eval': 5.476077526824481e-07}
# {'dim': {'x': 1.0005616547716942, 'y': 2.9994745038665656}, 'sigma': {'x': 0.008351362997140482, 'y': 0.009017340927286711}, 'eval': 5.96832057304345e-07}
# ...

# %%
def allowed_interval(**kwargs):
    if -10 <= kwargs['x'] <= 10 and -10 <= kwargs['y'] <= 10:
        return True
    return False


res = populational_non_isotropic_ES(expr="- abs (sin(x)*cos(y)*exp(abs(1 - ((sqrt(x^2 +y^2))/PI))))",
                                validator=allowed_interval, dimension_gen_interval=(-10, 10), sigma_var=0.5, iter=50,
                                seed=0, num_parents=1000, num_offspring=10)

x_array = [i['dim']['x'] for i in res]
y_array = [i['dim']['y'] for i in res]

plt.plot(x_array, y_array, 'ro')
plt.axis([-10, 10, -10, 10])
plt.show()
print('\n'.join([str(d) for d in res]))

print(x_array)
print(y_array)

# %%
def allowed_interval(**kwargs):
    if -15 <= kwargs['x'] <= -5 and -3 <= kwargs['y'] <= 3:
        return True
    return False


res = populational_non_isotropic_ES(expr="100*sqrt(abs(y-0.01*x^2)) + 0.01*abs(x+10)", validator=allowed_interval,
                                dimension_gen_interval=(-15, 15), sigma_var=0.5, iter=50, seed=0, num_parents=1000,
                                num_offspring=10)

x_array = [i['dim']['x'] for i in res]
y_array = [i['dim']['y'] for i in res]

plt.plot(x_array, y_array, 'ro')
plt.axis([-13, -5, -4, 6])
plt.show()
print('\n'.join([str(d) for d in res]))
